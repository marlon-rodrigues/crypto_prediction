# %%
import math
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
from scipy.stats import ks_2samp
# %matplotlib inline

from sklearn import metrics
from sklearn import preprocessing, cross_validation
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

import keras
from keras.layers import Dense, Dropout, Input, LSTM, Activation
from keras.models import Model,Sequential
from keras.layers.advanced_activations import LeakyReLU
from keras.optimizers import Adam, RMSprop
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# Read Datasets 
research_data_raw = pd.read_csv('Datasets/bitcoin_research_data_v2.csv')

# Drop unnecessary columns
research_data = research_data_raw.drop('Unnamed: 0', axis=1)
research_data.head()
# Out:
#          Date  Symbol    Open    High     Low   Close  Volume BTC  \
# 0  2019-05-11  BTCUSD  6337.9  6984.8  6337.9  6793.5     9855.87
# 1  2019-05-10  BTCUSD  6151.4  6430.0  6110.1  6337.9     9872.86
# 2  2019-05-09  BTCUSD  5939.6  6174.0  5933.2  6151.4     7405.18
# 3  2019-05-08  BTCUSD  5744.0  5983.2  5660.0  5939.6     6007.11
# 4  2019-05-07  BTCUSD  5687.4  5955.8  5687.4  5906.7     3668.12
#
#     Volume USD  Popularity  Popularity_Normalized
# 0  66133073.75        12.0                 1200.0
# 1  62166515.28        12.0                 1200.0
# 2  44816872.39        12.0                 1200.0
# 3  35184697.52        12.0                 1200.0
# 4  21496575.65        12.0                 1200.0

# %%
# Set Date column as index and drop other columns that won't be used by the model
research_data = research_data.set_index('Date')
research_data.index = pd.to_datetime(research_data.index)
research_data = research_data.sort_index()
research_data = research_data.drop(['Symbol','Popularity_Normalized','Volume BTC','Volume USD'], 1)
research_data.head()
# Out:
#               Open    High     Low   Close  Popularity
# Date
# 2014-05-18  453.83  453.83  445.56  445.56         2.0
# 2014-05-19  445.56  445.56  445.56  445.56         2.0
# 2014-05-20  445.56  498.84  445.56  493.43         2.0
# 2014-05-21  493.43  497.67  490.85  494.77         2.0
# 2014-05-22  494.77  530.00  494.77  530.00         2.0

# %%
# Get lenght of dataset
print(len(research_data))
# Out:
# 1808

# %%
# Check for null values
research_data.isna().sum()
# Out:
# Open          0
# High          0
# Low           0
# Close         0
# Popularity    0
# dtype: int64

# %%
# Define constants
TIME_STEPS = 10
TEST_SIZE = 0.1
EPOCHS = 400
BATCH_SIZE_NN = 4
GAN_TRAIN_BATCH_SIZE = 8
FEATURES = len(research_data.columns)

# %%
# Define train_test split function
def train_test_split(df, test_size):
    splitting_point = len(df) - int(test_size * len(df))
    train_data = df.iloc[:splitting_point]
    test_data = df.iloc[splitting_point:]
    return train_data, test_data

# %%
# Define plot function
def line_plot(line1, line2, label1=None, label2=None, title=''):
    fig, ax = plt.subplots(1, figsize=(16, 9))
    ax.plot(line1, label=label1, linewidth=2)
    ax.plot(line2, label=label2, linewidth=2)
    ax.set_ylabel('price [USD]', fontsize=14)
    ax.set_title(title, fontsize=18)
    ax.legend(loc='best', fontsize=18)

# %%
# Plot train and test sets
train, test = train_test_split(research_data, TEST_SIZE)
line_plot(train.Close, test.Close, 'training set', 'test set', 'BTC')

# %%
# Define function to normalize data with respect to first entry in the sequence. The first instance in the 
# sequence will always be zero (df / df.iloc[0] - 1) and all other instances will be relative to that first
# instance, representing the rate of change in the sequence
def get_rate_change_zero_base(df):
    return df / df.iloc[0] - 1

# %%
# Define function to convert dataframe into numpy array of sequences
def build_sequence(df, window_size):
    sequence_data = []
    for idx in range(len(df) - window_size):
        temp_data = df[idx: (idx + window_size)].copy()
        temp_data = get_rate_change_zero_base(temp_data)
        sequence_data.append(temp_data.values)
    return np.array(sequence_data)

# %%
# Define function to get training and test sets for GAN
def get_data(df, window_size, test_size):
    # train test split
    train_data, test_data = train_test_split(df, test_size)
    
    # extract sequence from data
    X_train = build_sequence(train_data, window_size)
    X_test = build_sequence(test_data, window_size)
    
    # extract targets
    y_train = train_data.Close[window_size:].values / train_data.Close[:-window_size].values - 1
    y_test = test_data.Close[window_size:].values / test_data.Close[:-window_size].values - 1
    
    return train_data, test_data, X_train, X_test, y_train, y_test

# %%
# Get the proper sets for GAN
train, test, X_train, X_test, y_train, y_test = get_data(research_data, TIME_STEPS, TEST_SIZE)

# Print set shapes
print('X_train shape: ' + str(X_train.shape))
print('y_train shape: ' + str(y_train.shape))
print('X_test shape: ' + str(X_test.shape))
print('y_test shape: ' + str(y_test.shape))
# Out:
# X_train shape: (1618, 10, 5)
# y_train shape: (1618,)
# X_test shape: (170, 10, 5)
# y_test shape: (170,)

# %%
# Create Generator Model and get its summary
def create_generator():
    optimizer = RMSprop(lr=0.005, clipvalue=1.)
    
    generator = Sequential()
    generator.add(LSTM(16, batch_input_shape=(BATCH_SIZE_NN, TIME_STEPS, FEATURES), return_sequences=True))
    generator.add(LeakyReLU(0.05))
    generator.add(LSTM(32,return_sequences=True))
    generator.add(LeakyReLU(0.05))
    generator.add(Dropout(0.5))
    generator.add(LSTM(64,return_sequences=False))
    generator.add(Dense(FEATURES))
    generator.add(Activation('tanh'))
    
    generator.compile(loss='mean_absolute_error', optimizer=optimizer)

    return generator

generator = create_generator()
generator.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_4 (LSTM)                (4, 10, 16)               1408
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (4, 10, 16)               0
# _________________________________________________________________
# lstm_5 (LSTM)                (4, 10, 32)               6272
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (4, 10, 32)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (4, 10, 32)               0
# _________________________________________________________________
# lstm_6 (LSTM)                (4, 64)                   24832
# _________________________________________________________________
# dense_7 (Dense)              (4, 5)                    325
# _________________________________________________________________
# activation_3 (Activation)    (4, 5)                    0
# =================================================================
# Total params: 32,837
# Trainable params: 32,837
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Create Discriminator Model and get its summary
def create_discriminator():
    optimizer = RMSprop(lr=0.0002, decay=6e-8)

    discriminator=Sequential()

    discriminator.add(Dense(units=32, batch_input_shape=(GAN_TRAIN_BATCH_SIZE, TIME_STEPS, FEATURES)))
    discriminator.add(LeakyReLU(0.01))
    discriminator.add(Dense(units=64))
    discriminator.add(LeakyReLU(0.01))
    discriminator.add(Dense(units=128))
    discriminator.add(LeakyReLU(0.01))
    discriminator.add(Dense(units=220,activation='linear'))
    discriminator.add(Activation('relu'))
    discriminator.add(Dense(1,activation='linear'))
    
    discriminator.compile(loss='mean_absolute_error', optimizer=optimizer)
    
    return discriminator

discriminator = create_discriminator()
discriminator.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (8, 10, 32)               192
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (8, 10, 32)               0
# _________________________________________________________________
# dense_9 (Dense)              (8, 10, 64)               2112
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (8, 10, 64)               0
# _________________________________________________________________
# dense_10 (Dense)             (8, 10, 128)              8320
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (8, 10, 128)              0
# _________________________________________________________________
# dense_11 (Dense)             (8, 10, 220)              28380
# _________________________________________________________________
# activation_4 (Activation)    (8, 10, 220)              0
# _________________________________________________________________
# dense_12 (Dense)             (8, 10, 1)                221
# =================================================================
# Total params: 39,225
# Trainable params: 39,225
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Create GAN with Generator and Discriminator and get its summary
def create_gan(discriminator, generator):
    optimizer = RMSprop(lr=0.0001, decay=3e-8) 
    discriminator.trainable=False
    
    gan_input = Input(shape=(TIME_STEPS, FEATURES))
    generated_data = generator(gan_input)
    gan_output= discriminator(generated_data)
    gan = Model(inputs=gan_input, outputs=gan_output)
    
    gan.compile(loss='mean_absolute_error', optimizer=optimizer)
    
    return gan

gan = create_gan(discriminator, generator)
gan.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 10, 5)             0
# _________________________________________________________________
# sequential_3 (Sequential)    multiple                  32837
# _________________________________________________________________
# sequential_4 (Sequential)    multiple                  39225
# =================================================================
# Total params: 72,062
# Trainable params: 32,837
# Non-trainable params: 39,225
# _________________________________________________________________

# %%
# Define values to be tracked during GAN training
gan_loss = []
discrimator_loss = []

# %%
# Define GAN training function
def train_gan(epochs, batch_size):
    # Make sure global variables are accessible within the training function
    global adversarial_loss
    global discrimator_loss
    
    global generator
    global discriminator
    global gan

    global X_train
    global X_test
    global y_train
    global y_test
    
    for e in range(1, epochs+1):
        print("Epoch %d" %e)
        for i in range(batch_size):
            # Generate noise data - with same shape as the traning data
            noise = np.float32(np.random.normal(size=[BATCH_SIZE_NN, TIME_STEPS, FEATURES]))
            
            # Generate fake prices from noise data
            generated_prices = generator.predict(noise) # Shape = (4,5)
            
            # Get a random set of real prices
            prices_batch = X_train[np.random.randint(low=0, high=X_train.shape[0], size=BATCH_SIZE_NN)]
            
            # Get generated prices to have the same shape as the training data
            generated_prices_dim = generated_prices.shape[0]
            gen_prices = np.zeros((generated_prices_dim, TIME_STEPS, FEATURES)) # Shape = (4,10,5)
            for j in range(generated_prices_dim):
                gen_prices[j] = generated_prices[j]
            
            # Construct batch with real and fake data 
            X_dis = np.concatenate([prices_batch, gen_prices])
            X_dis_dim = X_dis.shape[0]
            
            # Construct labels batch for generated and real data
            y_dis = np.zeros(shape=(X_dis_dim, TIME_STEPS, 1))
            y_dis[:int((X_dis_dim/2))] = 0.9 # label 0.9 is assigned to real data
            
            # Pre train discriminator on fake and real data before starting the gan. 
            discriminator.trainable = True
            d_loss = discriminator.train_on_batch(X_dis, y_dis)
            
            # Tricking the noised input of the Generator as real data
            noise = np.float32(np.random.normal(size=[BATCH_SIZE_NN, TIME_STEPS, FEATURES]))
            y_gen = np.ones(BATCH_SIZE_NN)
            
            # During the training of gan, the weights of discriminator should be fixed. 
            discriminator.trainable=False
            
            # Training the GAN by alternating the training of the Discriminator 
            # and training the chained GAN model with Discriminator’s weights freezed.
            g_loss = gan.train_on_batch(noise, y_gen)
            
            discrimator_loss.append(d_loss)
            gan_loss.append(g_loss)
            
            if i == (batch_size-1):
                log_mesg = "%d: [Discriminator loss: %f]" % (e, d_loss)
                log_mesg = "%s  [GAN loss: %f]" % (log_mesg, g_loss)
                print(log_mesg)

# %%
# Train GAN
train_gan(EPOCHS, GAN_TRAIN_BATCH_SIZE)
# Out:
# Epoch 1
# 1: [Discriminator loss: 0.183062]  [GAN loss: 0.714872]
# Epoch 2
# 2: [Discriminator loss: 0.258396]  [GAN loss: 0.770660]
# Epoch 3
# 3: [Discriminator loss: 0.254357]  [GAN loss: 0.626903]
# Epoch 4
# 4: [Discriminator loss: 0.118566]  [GAN loss: 0.897425]
# Epoch 5
# 5: [Discriminator loss: 0.207635]  [GAN loss: 0.893170]
# Epoch 6
# 6: [Discriminator loss: 0.097051]  [GAN loss: 0.457883]
# Epoch 7
# 7: [Discriminator loss: 0.225706]  [GAN loss: 0.723203]
# Epoch 8
# 8: [Discriminator loss: 0.303962]  [GAN loss: 0.771754]
# Epoch 9
# 9: [Discriminator loss: 0.248684]  [GAN loss: 0.797435]
# Epoch 10
# 10: [Discriminator loss: 0.154398]  [GAN loss: 0.957263]
# Epoch 11
# 11: [Discriminator loss: 0.152266]  [GAN loss: 0.441013]
# Epoch 12
# 12: [Discriminator loss: 0.461418]  [GAN loss: 0.490908]
# Epoch 13
# 13: [Discriminator loss: 0.199435]  [GAN loss: 0.696889]
# Epoch 14
# 14: [Discriminator loss: 0.250920]  [GAN loss: 0.650346]
# Epoch 15
# 15: [Discriminator loss: 0.225080]  [GAN loss: 0.628627]
# Epoch 16
# 16: [Discriminator loss: 0.204442]  [GAN loss: 0.633082]
# Epoch 17
# 17: [Discriminator loss: 0.152653]  [GAN loss: 0.260463]
# Epoch 18
# 18: [Discriminator loss: 0.097331]  [GAN loss: 0.497016]
# Epoch 19
# 19: [Discriminator loss: 0.270880]  [GAN loss: 0.433686]
# Epoch 20
# 20: [Discriminator loss: 0.234069]  [GAN loss: 0.534433]
# Epoch 21
# 21: [Discriminator loss: 0.217949]  [GAN loss: 0.433784]
# Epoch 22
# 22: [Discriminator loss: 0.104115]  [GAN loss: 0.497560]
# Epoch 23
# 23: [Discriminator loss: 0.337512]  [GAN loss: 0.666865]
# Epoch 24
# 24: [Discriminator loss: 0.254269]  [GAN loss: 0.607235]
# Epoch 25
# 25: [Discriminator loss: 0.261401]  [GAN loss: 0.667400]
# Epoch 26
# 26: [Discriminator loss: 0.423216]  [GAN loss: 0.634066]
# Epoch 27
# 27: [Discriminator loss: 0.233073]  [GAN loss: 0.812706]
# Epoch 28
# 28: [Discriminator loss: 0.330674]  [GAN loss: 0.575839]
# Epoch 29
# 29: [Discriminator loss: 0.512891]  [GAN loss: 0.745116]
# Epoch 30
# 30: [Discriminator loss: 0.154051]  [GAN loss: 0.767160]
# Epoch 31
# 31: [Discriminator loss: 0.373880]  [GAN loss: 0.608991]
# Epoch 32
# 32: [Discriminator loss: 0.316957]  [GAN loss: 0.607165]
# Epoch 33
# 33: [Discriminator loss: 0.424067]  [GAN loss: 0.959786]
# Epoch 34
# 34: [Discriminator loss: 0.156530]  [GAN loss: 0.494091]
# 369: [Discriminator loss: 0.297133]  [GAN loss: 0.525021]
# Epoch 370
# 370: [Discriminator loss: 0.244428]  [GAN loss: 0.653112]
# Epoch 371
# 371: [Discriminator loss: 0.320747]  [GAN loss: 0.793175]
# Epoch 372
# 372: [Discriminator loss: 0.206779]  [GAN loss: 0.783196]
# Epoch 373
# 373: [Discriminator loss: 0.254755]  [GAN loss: 0.769641]
# Epoch 374
# 374: [Discriminator loss: 0.281929]  [GAN loss: 0.538225]
# Epoch 375
# 375: [Discriminator loss: 0.112426]  [GAN loss: 0.894454]
# Epoch 376
# 376: [Discriminator loss: 0.320328]  [GAN loss: 0.464801]
# Epoch 377
# 377: [Discriminator loss: 0.237971]  [GAN loss: 0.476779]
# Epoch 378
# 378: [Discriminator loss: 0.134440]  [GAN loss: 1.050493]
# Epoch 379
# 379: [Discriminator loss: 0.217644]  [GAN loss: 0.696090]
# Epoch 380
# 380: [Discriminator loss: 0.290653]  [GAN loss: 0.377182]
# Epoch 381
# 381: [Discriminator loss: 0.156332]  [GAN loss: 0.717220]
# Epoch 382
# 382: [Discriminator loss: 0.124878]  [GAN loss: 0.580901]
# Epoch 383
# 383: [Discriminator loss: 0.130578]  [GAN loss: 0.885570]
# Epoch 384
# 384: [Discriminator loss: 0.193524]  [GAN loss: 0.351814]
# Epoch 385
# 385: [Discriminator loss: 0.295046]  [GAN loss: 0.672365]
# Epoch 386
# 386: [Discriminator loss: 0.266030]  [GAN loss: 0.571046]
# Epoch 387
# 387: [Discriminator loss: 0.294513]  [GAN loss: 0.740272]
# Epoch 388
# 388: [Discriminator loss: 0.089914]  [GAN loss: 0.684016]
# Epoch 389
# 389: [Discriminator loss: 0.265353]  [GAN loss: 0.474872]
# Epoch 390
# 390: [Discriminator loss: 0.278100]  [GAN loss: 0.732152]
# Epoch 391
# 391: [Discriminator loss: 0.127890]  [GAN loss: 0.604597]
# Epoch 392
# 392: [Discriminator loss: 0.223785]  [GAN loss: 0.784554]
# Epoch 393
# 393: [Discriminator loss: 0.305273]  [GAN loss: 0.810446]
# Epoch 394
# 394: [Discriminator loss: 0.189248]  [GAN loss: 0.478790]
# Epoch 395
# 395: [Discriminator loss: 0.354618]  [GAN loss: 0.707121]
# Epoch 396
# 396: [Discriminator loss: 0.246041]  [GAN loss: 0.920403]
# Epoch 397
# 397: [Discriminator loss: 0.177579]  [GAN loss: 0.792129]
# Epoch 398
# 398: [Discriminator loss: 0.125457]  [GAN loss: 0.686102]
# Epoch 399
# 399: [Discriminator loss: 0.217845]  [GAN loss: 0.435140]
# Epoch 400
# 400: [Discriminator loss: 0.332947]  [GAN loss: 0.463749]

# %%
# Plot GAN losses
ax = pd.DataFrame(
    {
        'GAN Loss': gan_loss,
        'Discriminative Loss': discrimator_loss,
    }
).plot(title='Training loss', figsize=(16, 9), logy=True)
ax.set_xlabel("Training iterations")
ax.set_ylabel("Loss")
# Out:
# Text(0,0.5,'Loss')

# %%
# Run model against test set
predictions = gan.predict(X_test).squeeze()

# %%
# Get the prediction metrics of the model
print("The Mean Absolute Error: %.5f" % metrics.mean_absolute_error(y_test, predictions))  
print("The Median Absolute Error: %.5f" % metrics.median_absolute_error(y_test, predictions)) 
print("The Mean Squared Error: %.5f" % metrics.mean_squared_error(y_test, predictions)) 
print("The Root Mean Squared Error: %.5f" % (np.sqrt(metrics.mean_squared_error(y_test, predictions))))
# Out:
# The Mean Absolute Error: 0.10205
# The Median Absolute Error: 0.07409
# The Mean Squared Error: 0.01897
# The Root Mean Squared Error: 0.13772

# %%
# Run Kolmogorov Smirnov test to verify the null hypothesis that the two samples (y_test and predictions) 
# are drawn from the same distribution
value, pValue = ks_2samp(y_test, predictions)

print("Kolmogorov Smirnov Test Statistic =", value, "  ", "pValue = ", pValue)

if pValue > 0.05:
	print('Samples are likely drawn from the same distributions (do not reject H0)')
else:
	print('Samples are likely drawn from different distributions (reject H0)')
# Out:
# Kolmogorov Smirnov Test Statistic = 0.5411764705882353    pValue =  1.1350250723748625e-22
# Samples are likely drawn from different distributions (reject H0)

# %%
# Get statistics summary over real and generated data
results = pd.DataFrame({'Real':y_test, 'Generated': predictions})
print(results.describe())
results.boxplot()
results.hist(bins=10)
# Out:
#         Generated        Real
# count  170.000000  170.000000
# mean    -0.037560    0.004384
# std      0.013107    0.131545
# min     -0.063942   -0.326316
# 25%     -0.047665   -0.053946
# 50%     -0.040367    0.005438
# 75%     -0.028993    0.059829
# max      0.007631    0.338482
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f971fbe45c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f971fc078d0>]],
#       dtype=object)

# %%
# Plot model predictions against actual data

# 1. Given that the final value is based on rate change, the prediction value is multiplied by the BTC price,
# which is the value previous to the defined TIME_STEPS, thus the future value is based on the formula:
# (CURR_VALUE from -TIME_STEPS days) * PREDICTED_VALUE_DENORMALIZED
# 2. Apply the same value used during the normalization for rate change calculation (df / df.iloc[0] - 1)
prediction_monetary_values = test.Close.values[:-TIME_STEPS] * (predictions + 1)
model_targets = test.Close[TIME_STEPS:]
prediction_series = pd.Series(index=model_targets.index, data=prediction_monetary_values)

# Apply shift to get graphs aligned
line_plot(model_targets[:][:-TIME_STEPS], prediction_series.shift(-TIME_STEPS), 'actual', 'prediction')

# %%
# Save model

# %%
# Serialize model to JSON
model_json = gan.to_json()
with open("Model_Files/gan_model.json", "w") as json_file:
    json_file.write(model_json)

# serialize weights to HDF5
gan.save_weights("Model_Files/gan_model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
from keras.models import model_from_json
 
# load json and create model
json_file = open('Model_Files/gan_model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("Model_Files/gan_model.h5")
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %%
predictions_loaded = loaded_model.predict(X_test).squeeze()

# %%
# Get the prediction metrics of the model
print("The Mean Absolute Error: %.5f" % metrics.mean_absolute_error(y_test, predictions_loaded))  
print("The Median Absolute Error: %.5f" % metrics.median_absolute_error(y_test, predictions_loaded)) 
print("The Mean Squared Error: %.5f" % metrics.mean_squared_error(y_test, predictions_loaded)) 
print("The Root Mean Squared Error: %.5f" % (np.sqrt(metrics.mean_squared_error(y_test, predictions_loaded))))
# Out:
# The Mean Absolute Error: 0.10205
# The Median Absolute Error: 0.07409
# The Mean Squared Error: 0.01897
# The Root Mean Squared Error: 0.13772
